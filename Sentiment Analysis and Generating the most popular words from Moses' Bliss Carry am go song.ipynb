# %%
import pandas as pd

# Try different delimiters to see which one works
delimiters = [',', '\t', ';']

# Attempt to read the file with each delimiter
for delimiter in delimiters:
    try:
        data = pd.read_csv(r"C:\Users\nanaa\Downloads\Untitled spreadsheet - Moses bliss song.csv", delimiter=delimiter)
        # Display the first few rows of the DataFrame
        print(f"Delimiter: '{delimiter}'")
        print(data.head())
        print("\n")
    except Exception as e:
        print(f"Failed to read with delimiter '{delimiter}': {e}")
# Out:
# Delimiter: ','
#                                  Channel URL                Name  \
# 0    http://www.youtube.com/@odeliamonic6034    @odeliamonic6034
# 1    http://www.youtube.com/@odeliamonic6034    @odeliamonic6034
# 2      http://www.youtube.com/@Jesusbabe6464      @Jesusbabe6464
# 3  http://www.youtube.com/@JoyEmmanuel-mg9ui  @JoyEmmanuel-mg9ui
# 4        http://www.youtube.com/@NonozaQueen        @NonozaQueen
#
#                                              Comment                  Time  \
# 0   Looking for where I can double like the video 🥰🥰  2024-07-15T23:22:47Z
# 1   Looking for where I can double like the video 🥰🥰  2024-07-15T23:22:47Z
# 2                        Wow this is so beautiful 😊❤  2024-07-13T16:38:22Z
# 3                  Who was crying while watching 😴🙏🙏  2024-07-13T08:07:12Z
# 4  This is the most beautiful wedding video I&#39...  2024-07-13T07:54:11Z
#
#    Likes  Reply Count Reply Author Reply Published Updated
# ...

# %%
import pandas as pd

# Use the correct delimiter that worked for your CSV file
correct_delimiter = ','  # Replace with the correct delimiter

# Read the CSV file with the correct delimiter
data = pd.read_csv(r"C:\Users\nanaa\Downloads\Untitled spreadsheet - Moses bliss song.csv", delimiter=correct_delimiter)

# Display the DataFrame to ensure all columns are separated correctly
print(data)

# Display the column names to verify
print("Column names:", data.columns.tolist())
# Out:
#                                          Channel URL                     Name  \
# 0            http://www.youtube.com/@odeliamonic6034         @odeliamonic6034
# 1            http://www.youtube.com/@odeliamonic6034         @odeliamonic6034
# 2              http://www.youtube.com/@Jesusbabe6464           @Jesusbabe6464
# 3          http://www.youtube.com/@JoyEmmanuel-mg9ui       @JoyEmmanuel-mg9ui
# 4                http://www.youtube.com/@NonozaQueen             @NonozaQueen
# ...                                              ...                      ...
# 3320        http://www.youtube.com/@beautytawiah7021        @beautytawiah7021
# 3321  http://www.youtube.com/@Hilaire-Keikel-ANATTOH  @Hilaire-Keikel-ANATTOH
# 3322         http://www.youtube.com/@user-no3br1qd4o         @user-no3br1qd4o
# 3323                http://www.youtube.com/@MAUWA122                @MAUWA122
# 3324            http://www.youtube.com/@davidmathias            @davidmathias
#
# ...

# %%
import nltk
from nltk.corpus import stopwords
from collections import Counter
import pandas as pd

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('stopwords')

# Define the text preprocessing function
def preprocess_text(text):
    if isinstance(text, str):
        words = nltk.word_tokenize(text)  # Tokenize the text
        words = [word.lower() for word in words if word.isalpha()]  # Lowercase and keep alphabetic words
        words = [word for word in words if word not in stopwords.words('english')]  # Remove stopwords
        return words
    else:
        return []

# Read the CSV file with the correct delimiter
correct_delimiter = ','  # Replace with the correct delimiter if needed
data = pd.read_csv(r"C:\Users\nanaa\Downloads\Untitled spreadsheet - Moses bliss song.csv", delimiter=correct_delimiter)

# Apply the preprocessing function to the 'Comment' column
data['cleaned_text'] = data['Comment'].apply(preprocess_text)

# Flatten the list of cleaned words and count their occurrences
all_words = [word for words in data['cleaned_text'] for word in words]
word_count = Counter(all_words)

# Display the most common words and their counts
most_common_words = word_count.most_common()
for word, count in most_common_words:
    print(f'{word}: {count}')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nanaa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nanaa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# god: 648
# beautiful: 573
# br: 503
# love: 446
# congratulations: 427
# bless: 341
# song: 263
# moses: 256
# bliss: 245
# may: 194
# marriage: 191
# wedding: 172
# union: 167
# jesus: 156
# video: 139
# wow: 134
# blessed: 127
# name: 122
# amen: 115
# home: 108
# marie: 106
# go: 99
# couple: 96
# tap: 93
# one: 87
# forever: 83
# blessings: 82
# like: 81
# good: 81
# much: 78
# lord: 75
# life: 67
# carry: 65
# amazing: 65
# man: 65
# blessing: 62
# mr: 61
# grace: 61
# watching: 59
# happy: 59
# wife: 59
# mrs: 58
# thank: 53
# sir: 52
# guys: 51
# best: 50
# music: 50
# watch: 49
# lovely: 47
# christ: 46
# glory: 46
# amp: 45
# married: 45
# na: 44
# ...

# %%
import nltk
from nltk.corpus import stopwords
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('stopwords')

# Define the text preprocessing function
def preprocess_text(text):
    if isinstance(text, str):
        words = nltk.word_tokenize(text)  # Tokenize the text
        words = [word.lower() for word in words if word.isalpha()]  # Lowercase and keep alphabetic words
        words = [word for word in words if word not in stopwords.words('english')]  # Remove stopwords
        return words
    else:
        return []

# Read the CSV file with pandas
data = pd.read_csv(r"C:\Users\nanaa\Downloads\Untitled spreadsheet - Moses bliss song.csv", delimiter=',')

# Combine all text from the 'Comment' column into a single string
all_text = ' '.join(data['Comment'].dropna().astype(str))

# Preprocess the text
tokens = preprocess_text(all_text)

# Count word frequencies
word_count = Counter(tokens)

# Get the N most common words
N = 20
most_common_words = word_count.most_common(N)

# Unpack words and counts
words, counts = zip(*most_common_words)

# Plot the results
plt.figure(figsize=(12, 6))
plt.bar(words, counts)
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Top {} Most Common Words".format(N))
plt.xticks(rotation=45)
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nanaa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nanaa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !pip install wordcloud

# %%
import nltk
from nltk.corpus import stopwords
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('stopwords')

# Define the text preprocessing function
def preprocess_text(text):
    if isinstance(text, str):
        words = nltk.word_tokenize(text)  # Tokenize the text
        words = [word.lower() for word in words if word.isalpha()]  # Lowercase and keep alphabetic words
        words = [word for word in words if word not in stopwords.words('english')]  # Remove stopwords
        return words
    else:
        return []

# Read the CSV file with pandas
data = pd.read_csv(r"C:\Users\nanaa\Downloads\Untitled spreadsheet - Moses bliss song.csv", delimiter=',')

# Combine all text from the 'Comment' column into a single string
all_text = ' '.join(data['Comment'].dropna().astype(str))

# Preprocess the text
tokens = preprocess_text(all_text)

# Count word frequencies
word_count = Counter(tokens)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_count)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud of Comments")
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nanaa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nanaa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Download NLTK resources if not already downloaded
nltk.download('vader_lexicon')

# Initialize the VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Read the CSV file
csv_file = r"C:\Users\nanaa\Downloads\Untitled spreadsheet - Moses bliss song.csv"
data = pd.read_csv(csv_file)

# Handle NaN values in 'Comment' column
data['Comment'] = data['Comment'].fillna('')  # Replace NaN with empty string

# Convert non-string values to strings
data['Comment'] = data['Comment'].astype(str)

# Function to determine sentiment
def get_sentiment(text):
    sentiment_scores = sid.polarity_scores(text)
    if sentiment_scores['compound'] >= 0.05:
        return "positive"
    elif sentiment_scores['compound'] <= -0.05:
        return "negative"
    else:
        return "neutral"

# Apply sentiment analysis to each comment
data['Sentiment'] = data['Comment'].apply(get_sentiment)

# Output the results
print(data[['Comment', 'Sentiment']])
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\nanaa\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                                                 Comment Sentiment
# 0      Looking for where I can double like the video 🥰🥰  positive
# 1      Looking for where I can double like the video 🥰🥰  positive
# 2                           Wow this is so beautiful 😊❤  positive
# 3                     Who was crying while watching 😴🙏🙏  negative
# 4     This is the most beautiful wedding video I&#39...  positive
# ...                                                 ...       ...
# 3320                  Wow May God bless your union❤❤🎉🎉🎉  positive
# 3321                                            Alright  positive
# 3322                                        Number one❤  positive
# 3323                                      ❤❤❤nice songs   neutral
# 3324                                  Congratulations 🎉  positive
#
# ...

# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# Download NLTK resources if not already downloaded
nltk.download('vader_lexicon')

# Initialize the VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Read the CSV file
csv_file = r"C:\Users\nanaa\Downloads\Untitled spreadsheet - Moses bliss song.csv"
data = pd.read_csv(csv_file)

# Handle NaN values in 'Comment' column
data['Comment'] = data['Comment'].fillna('')  # Replace NaN with empty string

# Convert non-string values to strings
data['Comment'] = data['Comment'].astype(str)

# Function to determine sentiment
def get_sentiment(text):
    sentiment_scores = sid.polarity_scores(text)
    if sentiment_scores['compound'] >= 0.05:
        return "positive"
    elif sentiment_scores['compound'] <= -0.05:
        return "negative"
    else:
        return "neutral"

# Apply sentiment analysis to each comment
data['Sentiment'] = data['Comment'].apply(get_sentiment)

# Count occurrences of each sentiment category
sentiment_counts = data['Sentiment'].value_counts()

# Plotting the sentiment distribution
plt.figure(figsize=(8, 6))
sentiment_counts.plot(kind='bar', color=['green', 'red', 'blue'])
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\nanaa\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
